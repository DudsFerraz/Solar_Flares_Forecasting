# %%
import os

import pandas as pd
from dotenv import load_dotenv

load_dotenv()

# %%
SLIDED_PATH = os.getenv('SLIDED_PATH')
slided_a = pd.read_parquet(os.path.join(SLIDED_PATH, "xray_slided.parquet"))

slided_a.head()

# %%
SLIDED_PATH = os.getenv('SLIDED_PATH')
slided_b = pd.read_parquet(os.path.join(SLIDED_PATH, "mag_global_slided.parquet"))

slided_b.head()

# %%
SLIDED_PATH = os.getenv('SLIDED_PATH')
slided_c = pd.read_parquet(os.path.join(SLIDED_PATH, "mag_regional_slided.parquet"))

slided_c.head(300)
