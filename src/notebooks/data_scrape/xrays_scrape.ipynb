# %% [markdown]
# ## Setup

# %%
import os
import re

import src.py_src.util as util
import pandas as pd
from dotenv import load_dotenv
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.firefox.service import Service
from selenium.webdriver.firefox.options import Options
from webdriver_manager.firefox import GeckoDriverManager
import time

# %%
load_dotenv()
save_path = os.getenv("XRAY_RAW_PATH")

# %% [markdown]
# ## Functions

# %%
def get_xray_source(date_: pd.Timestamp) -> tuple[str, str]:
    goes13_url = "https://www.ncei.noaa.gov/data/goes-space-environment-monitor/access/science/xrs/goes13/xrsf-l2-avg1m_science/"
    goes14_url = "https://www.ncei.noaa.gov/data/goes-space-environment-monitor/access/science/xrs/goes14/xrsf-l2-avg1m_science/"
    goes15_url = "https://www.ncei.noaa.gov/data/goes-space-environment-monitor/access/science/xrs/goes15/xrsf-l2-avg1m_science/"
    goes16_url = "https://data.ngdc.noaa.gov/platforms/solar-space-observing-satellites/goes/goes16/l2/data/xrsf-l2-avg1m_science/"

    # ====================================================================================
    # PERÍODO GOES-16 (Obrigatório por conta dos metadados de localização)
    # ====================================================================================
    # JUSTIFICATIVA: O artigo defects_and_inconsistencies (Seç. 2.3) afirma: "we include the full time range of
    # GOES-16 since 2017-02-19" para utilizar as coordenadas exatas das explosões.
    # Na Tabela 3, a coluna "Science-Quality" registra '16' em 2017-02-07 e
    # permanece em branco dali em diante (não há adoção do 17 ou 18 nessa coluna).
    # *Nota: Utilizando 2017-02-07 para seguir estritamente a data da Tabela 3.
    if date_ >= pd.Timestamp("2017-02-07"):
        return "g16", goes16_url

    # ====================================================================================
    # PERÍODO PRÉ-GOES-16 (Alternância baseada na coluna "Science-Quality" da Tabela 3)
    # ====================================================================================
    # JUSTIFICATIVA: "artigo defects_and_inconsistencies: Before GOES-16, we compiled science-quality data from various
    # GOES instruments based on their primary use status." (Seç. 2.3).
    # As datas abaixo mapeiam EXATAMENTE as mudanças da coluna "Science-Quality" da Tab 3,
    # de cima para baixo. Se a coluna está em branco em uma data, ela herda o valor de baixo.

    elif date_ >= pd.Timestamp("2016-06-09"):
        return "g15", goes15_url
    elif date_ >= pd.Timestamp("2016-05-12"):
        return "g14", goes14_url
    elif date_ >= pd.Timestamp("2015-06-09"):
        # Nota sobre a Tabela 3: Em 09/06/2015 houve duas mudanças no mesmo dia (para o 15 e depois para o 13).
        # A linha mais acima (mais recente na cronologia de eventos daquele dia) define o satélite '13'.
        return "g13", goes13_url
    elif date_ >= pd.Timestamp("2015-05-21"):
        return "g14", goes14_url
    elif date_ >= pd.Timestamp("2012-11-19"):
        return "g15", goes15_url
    elif date_ >= pd.Timestamp("2012-10-23"):
        return "g14", goes14_url
    elif date_ >= pd.Timestamp("2010-10-28"):
        return "g15", goes15_url
    elif date_ >= pd.Timestamp("2009-12-31"):
        return "g14", goes14_url

    raise ValueError(f"Data fora do intervalo suportado: {date_.date()}")

def download_xray_nc_data_selenium(years_range_: range, save_path_) -> None:
    save_path_abs = os.path.abspath(save_path_)
    os.makedirs(save_path_abs, exist_ok=True)
    print(f"Arquivos serão salvos em: '{save_path_abs}'")

    options = Options()
    options.set_preference("browser.download.folderList", 2)
    options.set_preference("browser.download.dir", save_path_abs)
    options.set_preference("browser.download.manager.showWhenStarting", False)
    options.set_preference("browser.helperApps.neverAsk.saveToDisk", "text/csv,application/octet-stream")
    driver = webdriver.Firefox(service=Service(GeckoDriverManager().install()), options=options)

    try:
        schedule: dict[tuple[int, str], set[str]] = {}
        for y_ in years_range_:
            for date_ in pd.date_range(start=f"{y_}-01-01", end=f"{y_}-12-31"):
                try:
                    _, base_url = get_xray_source(date_)
                except ValueError:
                    continue
                schedule.setdefault((y_, base_url), set()).add(f"{date_.month:02d}/")

        for (y_, base_url), target_months in sorted(schedule.items(), key=lambda item: (item[0][0], item[0][1])):

            print(f"Acessando a página principal: {base_url}")
            driver.get(base_url)
            time.sleep(2)

            links = driver.find_elements(By.XPATH, "//table/tbody/tr/td/a")
            year_link = None
            for link in links:
                if link.text.strip() == f"{y_}/":
                    year_link = link
                    break
            if year_link is None:
                print(f"AVISO: Ano {y_} não encontrado em {base_url}")
                continue
            year_link = year_link.get_attribute("href")

            driver.get(year_link)
            time.sleep(1)

            month_elements = driver.find_elements(By.XPATH, "//table/tbody/tr/td/a")
            month_links = {}
            for link in month_elements:
                text = link.text.strip()
                if re.fullmatch(r"\d{2}/", text):
                    month_links[text] = link.get_attribute("href")

            for month_dir in sorted(target_months):
                month_link = month_links.get(month_dir)
                if month_link is None:
                    print(f"  [MÊS] AVISO: Mês {month_dir} não encontrado para {y_} em {base_url}")
                    continue
                print(f"  [MÊS] Acessando mês: {month_link}")
                driver.get(month_link)
                time.sleep(1)

                day_elements = driver.find_elements(By.XPATH, "//table/tbody/tr/td/a")
                for file in day_elements:
                    if 'Parent Directory' not in file.text:
                        file_name_ = file.text.strip()

                        match_ = re.search(r'_d(\d{8})_', file_name_)
                        if match_:
                            file_date = pd.Timestamp(match_.group(1))

                            expected_sat, _ = get_xray_source(file_date)

                            current_sat_match = re.search(r'_g(\d{2})_', file_name_)
                            if current_sat_match:
                                current_sat = current_sat_match.group(1)

                                if expected_sat != f"g{current_sat}":
                                    print(f"        -> Ignorando {file_name_} (Satélite secundário no dia)")
                                    continue

                        file_path = os.path.join(save_path_abs, file_name_)
                        print(f"        -> Baixando {file_name_}...")
                        file.click()
                        util.wait_download(file_path=file_path, file_name=file_name_)

    except AttributeError as e:
        print(f"Erro de atributo: {e}")
    except Exception as e:
        print(f"Erro inesperado: {e}")
    finally:
        print("\nProcesso concluído. Fechando o navegador.")
        driver.quit()

    return None

# %% [markdown]
# ## Main

# %%
nc_range = range(2010, 2024 + 1)
download_xray_nc_data_selenium(nc_range,save_path)

# %% [markdown]
# ## Move Files

# %%
raw_root = os.path.abspath(save_path)
name_pattern = re.compile(r"^sci_xrsf-l2-avg1m_g\d{2}_d(?P<date>\d{8})_v\d+-\d+-\d+\.nc$")

moved_count = 0
skipped_count = 0
invalid_count = 0

for file_name in os.listdir(raw_root):
    src_path = os.path.join(raw_root, file_name)

    if not os.path.isfile(src_path) or not file_name.endswith(".nc"):
        continue

    match = name_pattern.match(file_name)
    if match is None:
        invalid_count += 1
        print(f"[INVALID] Nome fora do padrão, ignorando: {file_name}")
        continue

    year = match.group("date")[:4]
    year_dir = os.path.join(raw_root, year)
    os.makedirs(year_dir, exist_ok=True)

    dst_path = os.path.join(year_dir, file_name)
    if os.path.exists(dst_path):
        skipped_count += 1
        print(f"[SKIP] Já existe em destino: {dst_path}")
        continue

    os.replace(src_path, dst_path)
    moved_count += 1
    print(f"[MOVE] {file_name} -> {year_dir}")

print("\nResumo Move Files")
print(f"- movidos: {moved_count}")
print(f"- pulados: {skipped_count}")
print(f"- inválidos: {invalid_count}")

# %% [markdown]
# ## Check Files

# %%
origin_dir = save_path

current_y = -1
year_dir = str
files_in_y = set
for date in pd.date_range(start="2010-01-01", end="2024-12-31"):
    satellite, _ = get_xray_source(date)
    y = date.year
    m = f"{date.month:02d}"
    d = f"{date.day:02d}"

    if y != current_y:
        year_dir = os.path.join(save_path, str(y))
        if os.path.exists(year_dir):
            files_in_y = set(os.listdir(year_dir))
        else:
            files_in_y = set()
        current_y = y

    expected_prefix = f"sci_xrsf-l2-avg1m_{satellite}_d{y}{m}{d}"

    found = any(f.startswith(expected_prefix) for f in files_in_y)

    if not found:
        print(f"AVISO: Arquivo faltante! {y}-{m}-{d} (Satélite esperado: {satellite})")

# %%
check_output = """
AVISO: Arquivo faltante! 2010-03-22 (Satélite esperado: g14)
AVISO: Arquivo faltante! 2010-06-15 (Satélite esperado: g14)
AVISO: Arquivo faltante! 2010-08-22 (Satélite esperado: g14)
AVISO: Arquivo faltante! 2010-08-23 (Satélite esperado: g14)
AVISO: Arquivo faltante! 2010-12-18 (Satélite esperado: g15)
AVISO: Arquivo faltante! 2010-12-25 (Satélite esperado: g15)
AVISO: Arquivo faltante! 2011-10-26 (Satélite esperado: g15)
AVISO: Arquivo faltante! 2012-03-21 (Satélite esperado: g15)
AVISO: Arquivo faltante! 2012-03-22 (Satélite esperado: g15)
AVISO: Arquivo faltante! 2013-03-12 (Satélite esperado: g15)
AVISO: Arquivo faltante! 2013-03-13 (Satélite esperado: g15)
AVISO: Arquivo faltante! 2014-01-25 (Satélite esperado: g15)
AVISO: Arquivo faltante! 2014-02-08 (Satélite esperado: g15)
AVISO: Arquivo faltante! 2014-05-11 (Satélite esperado: g15)
AVISO: Arquivo faltante! 2014-11-13 (Satélite esperado: g15)
AVISO: Arquivo faltante! 2014-11-17 (Satélite esperado: g15)
AVISO: Arquivo faltante! 2014-12-13 (Satélite esperado: g15)
AVISO: Arquivo faltante! 2014-12-28 (Satélite esperado: g15)
AVISO: Arquivo faltante! 2014-12-30 (Satélite esperado: g15)
AVISO: Arquivo faltante! 2015-02-25 (Satélite esperado: g15)
AVISO: Arquivo faltante! 2015-06-22 (Satélite esperado: g13)
AVISO: Arquivo faltante! 2015-06-23 (Satélite esperado: g13)
AVISO: Arquivo faltante! 2015-06-24 (Satélite esperado: g13)
AVISO: Arquivo faltante! 2015-06-25 (Satélite esperado: g13)
AVISO: Arquivo faltante! 2016-03-10 (Satélite esperado: g13)
AVISO: Arquivo faltante! 2016-07-19 (Satélite esperado: g15)
AVISO: Arquivo faltante! 2016-09-12 (Satélite esperado: g15)
AVISO: Arquivo faltante! 2016-09-22 (Satélite esperado: g15)"""

# %%
## Retry Missing Files

import re as _re

# 2. Extrai as datas faltantes
missing_pattern = _re.compile(r"AVISO: Arquivo faltante! (\d{4}-\d{2}-\d{2})")
missing_dates = [
    pd.Timestamp(m.group(1))
    for m in missing_pattern.finditer(check_output)
]
print(f"Total de datas faltantes: {len(missing_dates)}")

# 3. Constrói o schedule APENAS com as datas faltantes
def build_schedule_from_dates(dates: list[pd.Timestamp]) -> dict[tuple[int, str], set[str]]:
    schedule = {}
    for date_ in dates:
        try:
            _, base_url = get_xray_source(date_)
        except ValueError:
            continue
        schedule.setdefault((date_.year, base_url), set()).add(f"{date_.month:02d}/")
    return schedule

missing_schedule = build_schedule_from_dates(missing_dates)
print(f"Combinações ano/URL a processar: {len(missing_schedule)}")

# 4. Roda o Selenium só para esse schedule reduzido
save_path_abs = os.path.abspath(save_path)
os.makedirs(save_path_abs, exist_ok=True)

options = Options()
options.set_preference("browser.download.folderList", 2)
options.set_preference("browser.download.dir", save_path_abs)
options.set_preference("browser.download.manager.showWhenStarting", False)
options.set_preference("browser.helperApps.neverAsk.saveToDisk", "text/csv,application/octet-stream")
driver = webdriver.Firefox(service=Service(GeckoDriverManager().install()), options=options)

try:
    for (y_, base_url), target_months in sorted(missing_schedule.items(), key=lambda item: (item[0][0], item[0][1])):

        print(f"Acessando: {base_url}")
        driver.get(base_url)
        time.sleep(2)

        links = driver.find_elements(By.XPATH, "//table/tbody/tr/td/a")
        year_link = None
        for link in links:
            if link.text.strip() == f"{y_}/":
                year_link = link
                break
        if year_link is None:
            print(f"AVISO: Ano {y_} não encontrado em {base_url}")
            continue
        year_link = year_link.get_attribute("href")

        driver.get(year_link)
        time.sleep(1)

        month_elements = driver.find_elements(By.XPATH, "//table/tbody/tr/td/a")
        month_links = {}
        for link in month_elements:
            text = link.text.strip()
            if re.fullmatch(r"\d{2}/", text):
                month_links[text] = link.get_attribute("href")

        for month_dir in sorted(target_months):
            month_link = month_links.get(month_dir)
            if month_link is None:
                print(f"  [MÊS] AVISO: Mês {month_dir} não encontrado para {y_} em {base_url}")
                continue
            print(f"  [MÊS] Acessando: {month_link}")
            driver.get(month_link)
            time.sleep(1)

            day_elements = driver.find_elements(By.XPATH, "//table/tbody/tr/td/a")
            for file in day_elements:
                if 'Parent Directory' not in file.text:
                    file_name_ = file.text.strip()

                    match_ = re.search(r'_d(\d{8})_', file_name_)
                    if match_:
                        file_date = pd.Timestamp(match_.group(1))

                        # Pula se a data não está na lista de faltantes
                        if file_date not in missing_dates:
                            continue

                        expected_sat, _ = get_xray_source(file_date)
                        current_sat_match = re.search(r'_g(\d{2})_', file_name_)
                        if current_sat_match:
                            current_sat = current_sat_match.group(1)
                            if expected_sat != f"g{current_sat}":
                                print(f"        -> Ignorando {file_name_} (Satélite secundário)")
                                continue

                    file_path = os.path.join(save_path_abs, file_name_)
                    print(f"        -> Baixando {file_name_}...")
                    file.click()
                    util.wait_download(file_path=file_path, file_name=file_name_)

except Exception as e:
    print(f"Erro: {e}")
finally:
    print("\nProcesso concluído. Fechando o navegador.")
    driver.quit()
