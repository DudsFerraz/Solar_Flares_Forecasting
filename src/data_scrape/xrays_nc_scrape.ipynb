# %% [markdown]
# ## Setup

# %%
import os
import re

import src.util as util
import pandas as pd
from dotenv import load_dotenv
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.firefox.service import Service
from selenium.webdriver.firefox.options import Options
from webdriver_manager.firefox import GeckoDriverManager
import time

# %%
load_dotenv()
save_path = os.getenv("XRAY_V2_PATH")

# %% [markdown]
# ## Functions

# %%
def download_xray_nc_data_selenium(years_range_: range, save_path_) -> None:
    save_path_abs = os.path.abspath(save_path_)
    os.makedirs(save_path_abs, exist_ok=True)
    print(f"Arquivos serão salvos em: '{save_path_abs}'")

    options = Options()
    options.set_preference("browser.download.folderList", 2)
    options.set_preference("browser.download.dir", save_path_abs)
    options.set_preference("browser.download.manager.showWhenStarting", False)
    options.set_preference("browser.helperApps.neverAsk.saveToDisk", "text/csv,application/octet-stream")
    driver = webdriver.Firefox(service=Service(GeckoDriverManager().install()), options=options)

    base_urls = ("https://data.ngdc.noaa.gov/platforms/solar-space-observing-satellites/goes/goes17/l2/data/xrsf-l2-avg1m_science/",
                 "https://data.ngdc.noaa.gov/platforms/solar-space-observing-satellites/goes/goes18/l2/data/xrsf-l2-avg1m_science/")

    try:
        for y_ in years_range_:
            if y_ <= 2022: base_url = base_urls[0]
            else: base_url = base_urls[1]

            print(f"Acessando a página principal: {base_url}")
            driver.get(base_url)
            time.sleep(2)

            links = driver.find_elements(By.XPATH, "//table/tbody/tr/td/a")
            # print(f"links:\n\n {links}")
            year_link = None
            for link in links:
                print(f"text: {link.text.strip()} |||||| y: {y_}" )
                if link.text.strip() == f"{y_}/":
                    year_link = link
                    break
            year_link = year_link.get_attribute("href")

            driver.get(year_link)
            time.sleep(1)

            month_elements = driver.find_elements(By.XPATH, "//table/tbody/tr/td/a")
            month_links = []
            for link in month_elements:
                if 'Parent Directory' not in link.text:
                    month_links.append(link.get_attribute("href"))

            for month_link in month_links:
                print(f"  [MÊS] Acessando mês: {month_link}")
                driver.get(month_link)
                time.sleep(1)

                day_elements = driver.find_elements(By.XPATH, "//table/tbody/tr/td/a")
                for file in day_elements:
                    if 'Parent Directory' not in file.text:
                        file_name = file.text.strip()
                        file_path = os.path.join(save_path_abs, file_name)
                        print(f"        -> Baixando {file_name}...")
                        file.click()
                        util.wait_download(file_path_=file_path, file_name_=file_name)

    except AttributeError as e:
        print(e)
    except Exception as e:
        print(e)
    finally:
        print("\nProcesso concluído. Fechando o navegador.")
        driver.quit()

    return None

# %% [markdown]
# ## Main

# %%
nc_range = range(2022,2025+1)
# download_xray_nc_data_selenium(nc_range,save_path)
download_xray_nc_data_selenium(range(2022,2022+1),save_path)
# Out:
# Arquivos serão salvos em: 'G:\My Drive\Solar_Flares\Data\xray_V2\raw'
# Acessando a página principal: https://data.ngdc.noaa.gov/platforms/solar-space-observing-satellites/goes/goes17/l2/data/xrsf-l2-avg1m_science/
# text: Parent Directory |||||| y: 2022
# text: 2018/ |||||| y: 2022
# text: 2019/ |||||| y: 2022
# text: 2020/ |||||| y: 2022
# text: 2021/ |||||| y: 2022
# text: 2022/ |||||| y: 2022
#   [MÊS] Acessando mês: https://data.ngdc.noaa.gov/platforms/solar-space-observing-satellites/goes/goes17/l2/data/xrsf-l2-avg1m_science/2022/01/
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220101_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220101_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220102_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220102_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220103_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220103_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220104_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220104_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220105_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220105_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220106_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220106_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220107_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220107_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220108_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220108_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220109_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220109_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220110_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220110_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220111_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220111_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220112_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220112_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220113_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220113_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220114_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220114_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220115_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220115_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220116_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220116_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220117_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220117_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220118_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220118_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220119_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220119_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220120_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220120_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220121_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220121_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220122_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220122_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220123_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220123_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220124_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220124_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220125_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220125_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220126_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220126_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220127_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220127_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220128_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220128_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220129_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220129_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220130_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220130_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220131_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220131_v2-2-0.nc' concluído com sucesso!
#   [MÊS] Acessando mês: https://data.ngdc.noaa.gov/platforms/solar-space-observing-satellites/goes/goes17/l2/data/xrsf-l2-avg1m_science/2022/02/
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220201_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220201_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220202_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220202_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220203_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220203_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220204_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220204_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220205_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220205_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220206_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220206_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220207_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220207_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220208_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220208_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220209_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220209_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220210_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220210_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220211_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220211_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220212_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220212_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220213_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220213_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220214_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220214_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220215_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220215_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220216_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220216_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220217_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220217_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220218_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220218_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220219_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220219_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220220_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220220_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220221_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220221_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220222_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220222_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220223_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220223_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220224_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220224_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220225_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220225_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220226_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220226_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220227_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220227_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220228_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220228_v2-2-0.nc' concluído com sucesso!
#   [MÊS] Acessando mês: https://data.ngdc.noaa.gov/platforms/solar-space-observing-satellites/goes/goes17/l2/data/xrsf-l2-avg1m_science/2022/03/
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220301_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220301_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220302_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220302_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220303_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220303_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220304_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220304_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220305_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220305_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220306_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220306_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220307_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220307_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220308_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220308_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220309_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220309_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220310_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220310_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220311_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220311_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220312_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220312_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220313_v2-2-0.nc...
#         -> Aguardando conclusão do download...
#         -> Download de 'sci_xrsf-l2-avg1m_g17_d20220313_v2-2-0.nc' concluído com sucesso!
#         -> Baixando sci_xrsf-l2-avg1m_g17_d20220314_v2-2-0.nc...

# %%
util.create_dirs(save_path,nc_range)

# %%
origin_dir = save_path
for date in pd.date_range(start="2020-01-01", end="2025-12-31"):
    y = date.year
    m = f"{date.month:02d}"
    d = f"{date.day:02d}"
    destiny_dir = os.path.join(save_path, str(y))
    file_name_pattern = re.compile(f"^sci_xrsf-l2-avg1m_g\\d{{2}}_d{y}{m}{d}_v2-2-0\.nc$")

    util.move_file(origin_dir, destiny_dir, file_name_pattern)
# Out:
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220101_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220102_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220103_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220104_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220105_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220106_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220107_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220108_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220109_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220110_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220111_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220112_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220113_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220114_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220115_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220116_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220117_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220118_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220119_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220120_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220121_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220122_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220123_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220124_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220125_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220126_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220127_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220128_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220129_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220130_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220131_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220201_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220202_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220203_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220204_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220205_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220206_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220207_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220208_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220209_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220210_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220211_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220212_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220213_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220214_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220215_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220216_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220217_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220218_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220219_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220220_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220221_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220222_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220223_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220224_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220225_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220226_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220227_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220228_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220301_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220302_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220303_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220304_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220305_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220306_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220307_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220308_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220309_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220310_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220311_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220312_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220313_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220314_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220315_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220316_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220317_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220318_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220319_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220320_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220321_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220322_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220323_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220324_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220325_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220326_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220327_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220328_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220329_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220330_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220331_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220401_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220402_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220403_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220404_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220405_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220406_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220407_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220408_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220409_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220410_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220411_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220412_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220413_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220414_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220415_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220416_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220417_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220418_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220419_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220420_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220421_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220422_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220423_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220424_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220425_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220426_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220427_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220428_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220429_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220430_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220501_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220502_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220503_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220504_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220505_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220506_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220507_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220508_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220509_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220510_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220511_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220512_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220513_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220514_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220515_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220516_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220517_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220518_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220519_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220520_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220521_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220522_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220523_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220524_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220525_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220526_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220527_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220528_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220529_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220530_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220531_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220601_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220602_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220603_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220604_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220605_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220606_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220607_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220608_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220609_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220610_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220611_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220612_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220613_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220614_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220615_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220616_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220617_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220618_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220619_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220620_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220621_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220622_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220623_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220624_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220625_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220626_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220627_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220628_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220629_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220630_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220701_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220702_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220703_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220704_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220705_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220706_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220707_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220708_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220709_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220710_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220711_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220712_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220713_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220714_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220715_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220716_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220717_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220718_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220719_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220720_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220721_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220722_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220723_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220724_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220725_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220726_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220727_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220728_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220729_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220730_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220731_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220801_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220802_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220803_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220804_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220805_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220806_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220807_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220808_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220809_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220810_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220811_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220812_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220813_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220814_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220815_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220816_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220817_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220818_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220819_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220820_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220821_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220822_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220823_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220824_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220825_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220826_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220827_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220828_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220829_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220830_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220831_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20220901_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20250922_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20250923_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20250924_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20250925_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20250926_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20250927_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20250928_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20250929_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20250930_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251001_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251002_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251003_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251004_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251005_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251006_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251007_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251008_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251009_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251010_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251011_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251012_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251013_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251014_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251015_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251016_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251017_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251018_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251019_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251020_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251021_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251022_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251023_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251024_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251025_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251026_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251027_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251028_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251029_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251030_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251031_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251101_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251102_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251103_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251104_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251105_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251106_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251107_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251108_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251109_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251110_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251111_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251112_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251113_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251114_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251115_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251116_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251117_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251118_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251119_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251120_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251121_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251122_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251123_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251124_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251125_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251126_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251127_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251128_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251129_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251130_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251201_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251202_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251203_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251204_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251205_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251206_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251207_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251208_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251209_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251210_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251211_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251212_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251213_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251214_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251215_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251216_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251217_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251218_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251219_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251220_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251221_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251222_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251223_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251224_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251225_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251226_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251227_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251228_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251229_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251230_v2-2-0\\.nc$')) NOT FOUND
# FILE (re.compile('^sci_xrsf-l2-avg1m_g\\d{2}_d20251231_v2-2-0\\.nc$')) NOT FOUND
